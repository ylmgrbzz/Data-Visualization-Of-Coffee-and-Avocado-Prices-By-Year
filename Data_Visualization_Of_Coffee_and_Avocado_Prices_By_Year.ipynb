# %% [markdown]
# <a href="https://colab.research.google.com/github/ylmgrbzz/Data-Visualization-Of-Coffee-and-Avocado-Prices-By-Year/blob/main/Data_Visualization_Of_Coffee_and_Avocado_Prices_By_Year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("avocado.csv")
df.head(3)
# Out:
#          date  average_price  total_volume       4046      4225   4770  \
# 0  2015-01-04           1.22      40873.28    2819.50  28287.42  49.90
# 1  2015-01-04           1.79       1373.95      57.42    153.88   0.00
# 2  2015-01-04           1.00     435021.49  364302.39  23821.16  82.15
#
#    total_bags  small_bags  large_bags  xlarge_bags          type  year  \
# 0     9716.46     9186.93      529.53          0.0  conventional  2015
# 1     1162.65     1162.65        0.00          0.0       organic  2015
# 2    46815.79    16707.15    30108.64          0.0  conventional  2015
#
#   geography
# 0    Albany
# 1    Albany
# 2   Atlanta

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33045 entries, 0 to 33044
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           33045 non-null  object
#  1   average_price  33045 non-null  float64
#  2   total_volume   33045 non-null  float64
#  3   4046           33045 non-null  float64
#  4   4225           33045 non-null  float64
#  5   4770           33045 non-null  float64
#  6   total_bags     33045 non-null  float64
#  7   small_bags     33045 non-null  float64
#  8   large_bags     33045 non-null  float64
#  9   xlarge_bags    33045 non-null  float64
#  10  type           33045 non-null  object
#  11  year           33045 non-null  int64
#  12  geography      33045 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 3.3+ MB

# %%
df["date"]=pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33045 entries, 0 to 33044
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           33045 non-null  datetime64[ns]
#  1   average_price  33045 non-null  float64
#  2   total_volume   33045 non-null  float64
#  3   4046           33045 non-null  float64
#  4   4225           33045 non-null  float64
#  5   4770           33045 non-null  float64
#  6   total_bags     33045 non-null  float64
#  7   small_bags     33045 non-null  float64
#  8   large_bags     33045 non-null  float64
#  9   xlarge_bags    33045 non-null  float64
#  10  type           33045 non-null  object
#  11  year           33045 non-null  int64
#  12  geography      33045 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(2)
# memory usage: 3.3+ MB

# %%
plt.plot(df["date"],df["average_price"])
plt.show()

# %%
dfgrup=df.groupby(by="date").mean()
dfgrup
# Out:
#             average_price  total_volume           4046           4225  \
# date
# 2015-01-04       1.301296  7.840216e+05  306465.358704  341213.318796
# 2015-01-11       1.370648  7.273686e+05  287260.786944  303781.757778
# 2015-01-18       1.391111  7.258221e+05  294469.507963  293167.054907
# 2015-01-25       1.397130  7.080211e+05  299121.600648  267862.244167
# 2015-02-01       1.247037  1.106048e+06  465675.823704  469409.541481
# ...                   ...           ...            ...            ...
# 2020-11-01       1.171574  1.164935e+06  286981.975370  208731.586944
# 2020-11-08       1.162778  1.155557e+06  292187.198426  200048.879907
# 2020-11-15       1.177685  1.139924e+06  277587.040648  207859.378333
# 2020-11-22       1.169352  1.056720e+06  278600.280185  182210.295463
# 2020-11-29       1.177500  9.308387e+05  251243.641852  153437.404352
#
#                     4770     total_bags     small_bags     large_bags  \
# date
# ...

# %%
plt.figure(figsize=(14,6))
plt.plot(dfgrup.index,dfgrup["average_price"])
plt.title("Avocado Fiyat Grafiği",fontdict={"fontsize":16})
plt.xlabel("Tarih",fontdict={"fontsize":12})
plt.ylabel("Fiyat(USD)",fontdict={"fontsize":12})
plt.show()

# %%
coffee=pd.read_csv("coffee.csv")
coffee.tail(3)
# Out:
#             Date    Open    High     Low   Close  Volume Currency
# 5743  2022-08-31  240.75  240.75  239.65  239.10      12      USD
# 5744  2022-09-01  238.55  238.55  236.60  236.35       6      USD
# 5745  2022-09-02  232.50  234.05  228.28  228.42       0      USD

# %%
coffee["Date"]=pd.to_datetime(coffee["Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5746 entries, 0 to 5745
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      5746 non-null   object
#  1   Open      5746 non-null   float64
#  2   High      5746 non-null   float64
#  3   Low       5746 non-null   float64
#  4   Close     5746 non-null   float64
#  5   Volume    5746 non-null   int64
#  6   Currency  5746 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 314.4+ KB

# %%
coffee.head(10)
# Out:
#         Date    Open    High     Low   Close  Volume Currency
# 0 2000-01-03  122.25  124.00  116.10  116.50    6640      USD
# 1 2000-01-04  116.25  120.50  115.75  116.25    5492      USD
# 2 2000-01-05  115.00  121.00  115.00  118.60    6165      USD
# 3 2000-01-06  119.00  121.40  116.50  116.85    5094      USD
# 4 2000-01-07  117.25  117.75  113.80  114.15    6855      USD
# 5 2000-01-10  123.50  126.00  116.70  117.55    7499      USD
# 6 2000-01-11  115.50  118.25  115.50  117.80    3976      USD
# 7 2000-01-12  117.80  120.50  116.90  118.95    5184      USD
# 8 2000-01-13  119.25  120.00  117.50  118.55    3717      USD
# 9 2000-01-14  117.75  120.25  112.25  112.55   10115      USD

# %%
coffee["price"]=(coffee["Close"]/25)*0.7
coffee.head(3)
# Out:
#         Date    Open   High     Low   Close  Volume Currency   price
# 0 2000-01-03  122.25  124.0  116.10  116.50    6640      USD  3.2620
# 1 2000-01-04  116.25  120.5  115.75  116.25    5492      USD  3.2550
# 2 2000-01-05  115.00  121.0  115.00  118.60    6165      USD  3.3208

# %%
coffee=coffee.set_index("Date")
coffee.head(5)
# Out:
#               Open    High     Low   Close  Volume Currency   price
# Date
# 2000-01-03  122.25  124.00  116.10  116.50    6640      USD  3.2620
# 2000-01-04  116.25  120.50  115.75  116.25    5492      USD  3.2550
# 2000-01-05  115.00  121.00  115.00  118.60    6165      USD  3.3208
# 2000-01-06  119.00  121.40  116.50  116.85    5094      USD  3.2718
# 2000-01-07  117.25  117.75  113.80  114.15    6855      USD  3.1962

# %%
coffee=coffee.reindex(pd.date_range("2000-01-03","2022-09-02",freq="D"))
coffee=coffee[["price"]]
coffee.head(10)
# Out:
#              price
# 2000-01-03  3.2620
# 2000-01-04  3.2550
# 2000-01-05  3.3208
# 2000-01-06  3.2718
# 2000-01-07  3.1962
# 2000-01-08     NaN
# 2000-01-09     NaN
# 2000-01-10  3.2914
# 2000-01-11  3.2984
# 2000-01-12  3.3306

# %%
coffee["price_cmt"]=coffee.shift(1)

# %%
coffee["price_pzr"]=coffee["price_cmt"].shift(1)

# %%
coffee.head(10)
# Out:
#              price  price_cmt  price_pzr
# 2000-01-03  3.2620        NaN        NaN
# 2000-01-04  3.2550     3.2620        NaN
# 2000-01-05  3.3208     3.2550     3.2620
# 2000-01-06  3.2718     3.3208     3.2550
# 2000-01-07  3.1962     3.2718     3.3208
# 2000-01-08     NaN     3.1962     3.2718
# 2000-01-09     NaN        NaN     3.1962
# 2000-01-10  3.2914        NaN        NaN
# 2000-01-11  3.2984     3.2914        NaN
# 2000-01-12  3.3306     3.2984     3.2914

# %%
coffee["price"]=coffee["price"].fillna(0)

# %%
coffee["price"]=np.where(coffee["price"]==0,coffee["price_cmt"],coffee["price"])

# %%
coffee["price"]=coffee["price"].fillna(0)
coffee["price"]=np.where(coffee["price"]==0,coffee["price_pzr"],coffee["price"])

# %%
coffee.head(10)
# Out:
#              price  price_cmt  price_pzr
# 2000-01-03  3.2620        NaN        NaN
# 2000-01-04  3.2550     3.2620        NaN
# 2000-01-05  3.3208     3.2550     3.2620
# 2000-01-06  3.2718     3.3208     3.2550
# 2000-01-07  3.1962     3.2718     3.3208
# 2000-01-08  3.1962     3.1962     3.2718
# 2000-01-09  3.1962        NaN     3.1962
# 2000-01-10  3.2914        NaN        NaN
# 2000-01-11  3.2984     3.2914        NaN
# 2000-01-12  3.3306     3.2984     3.2914

# %%
cof=coffee.loc[dfgrup.index]
cof
# Out:
#              price  price_cmt  price_pzr
# 2015-01-04  4.5094        NaN     4.5094
# 2015-01-11  5.0414        NaN     5.0414
# 2015-01-18  4.7880        NaN     4.7880
# 2015-01-25  4.5486        NaN     4.5486
# 2015-02-01  4.5332        NaN     4.5332
# ...            ...        ...        ...
# 2020-11-01  2.9232        NaN     2.9232
# 2020-11-08  2.9946        NaN     2.9946
# 2020-11-15  3.0590        NaN     3.0590
# 2020-11-22  3.2340        NaN     3.2340
# 2020-11-29  3.4076        NaN     3.4076
#
# [306 rows x 3 columns]

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(14,6))
plt.title("Kahve ve Avokado Fiyatı")
plt.plot(dfgrup.index,dfgrup["average_price"])
plt.plot(dfgrup.index,cof["price"])
plt.xlabel("Tarih")
plt.ylabel("Fiyat USD")
plt.legend("Avokado","Kahve")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Legend does not support 'A' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Legend does not support 'v' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Legend does not support 'o' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Legend does not support 'k' instances.
# ...
